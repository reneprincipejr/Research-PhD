# %%
import numpy as np
from google.colab import files
import warnings
from scipy.stats import pearsonr
warnings.filterwarnings('ignore')

# reminder that if you are installing libraries in a Google Colab instance you will be prompted to restart your kernal

try:
    import geemap, ee
    import seaborn as sns
    import matplotlib.pyplot as plt
except ModuleNotFoundError:
    if 'google.colab' in str(get_ipython()):
        print("package not found, installing w/ pip in Google Colab...")
        # !pip install geemap seaborn matplotlib
    else:
        print("package not found, installing w/ conda...")
        # !conda install mamba -c conda-forge -y
        # !mamba install geemap -c conda-forge -y
        # !conda install seaborn matplotlib -y
    import geemap, ee
    import seaborn as sns
    import matplotlib.pyplot as plt

# %%
try:
        ee.Initialize()
except Exception as e:
        ee.Authenticate()
        ee.Initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=gFfoh3j8ID9NB5vfNrFJCExsypfmB35vC_Tksmn9eeI&tc=eRpfsOuTJFXTJHUJ9vQuPW-swlqVGRJTVvTTdOkk12A&cc=T-JVvwRpBXGh0HR-doFARbsFsqjDMpVk9yP2G_vxnjc
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1AfJohXk0tgFW-fjlqdu18KLRtjb_f5NBbhUoCjDzD1XWWXwX-1Wl6dxiHCw
#
# Successfully saved authorization token.

# %%
import geopandas as gpd
import pandas as pd
import json
import ee
import matplotlib.pyplot as plt
from pprint import pprint
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
municities = gpd.read_file("/MuniCities.shp", crs='EPSG:4326')
municities
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#       ID_0  ISO       NAME_0  ID_1             NAME_1  ID_2       NAME_2  \
# 0      177  PHL  Philippines     1               Abra    20   Sallapadan
# 1      177  PHL  Philippines     1               Abra    21   San Isidro
# 2      177  PHL  Philippines     1               Abra    22     San Juan
# 3      177  PHL  Philippines     1               Abra    23  San Quintin
# 4      177  PHL  Philippines     1               Abra    24        Tayum
# ...    ...  ...          ...   ...                ...   ...          ...
# 1642   177  PHL  Philippines    81  Zamboanga del Sur  1623   San Miguel
# 1643   177  PHL  Philippines    81  Zamboanga del Sur  1624    San Pablo
# 1644   177  PHL  Philippines    81  Zamboanga del Sur  1625      Sominot
# 1645   177  PHL  Philippines    82  Zamboanga Sibugay  1646        Titay
# 1646   177  PHL  Philippines    82  Zamboanga Sibugay  1647     Tungawan
#
#      NL_NAME_2           VARNAME_2           TYPE_2     ENGTYPE_2  \
# 0         None                None  Bayan|Munisipyo  Municipality
# 1         None                None  Bayan|Munisipyo  Municipality
# 2         None                None  Bayan|Munisipyo  Municipality
# 3         None                None  Bayan|Munisipyo  Municipality
# 4         None                None  Bayan|Munisipyo  Municipality
# ...        ...                 ...              ...           ...
# 1642      None                None  Bayan|Munisipyo  Municipality
# 1643      None                None  Bayan|Munisipyo  Municipality
# 1644      None  Don Mariano Marcos  Bayan|Munisipyo  Municipality
# 1645      None                None  Bayan|Munisipyo  Municipality
# 1646      None                None  Bayan|Munisipyo  Municipality
#
#                PROVINCE                                  REGION  \
# 0                  Abra  Cordillera Administrative Region (CAR)
# 1                  Abra  Cordillera Administrative Region (CAR)
# 2                  Abra  Cordillera Administrative Region (CAR)
# 3                  Abra  Cordillera Administrative Region (CAR)
# 4                  Abra  Cordillera Administrative Region (CAR)
# ...                 ...                                     ...
# 1642  Zamboanga del Sur         Zamboanga Peninsula (Region IX)
# 1643  Zamboanga del Sur         Zamboanga Peninsula (Region IX)
# 1644  Zamboanga del Sur         Zamboanga Peninsula (Region IX)
# 1645  Zamboanga Sibugay         Zamboanga Peninsula (Region IX)
# 1646  Zamboanga Sibugay         Zamboanga Peninsula (Region IX)
#
#                                                geometry
# 0     POLYGON ((120.81813 17.45325, 120.80331 17.449...
# 1     POLYGON ((120.62464 17.44141, 120.62530 17.441...
# 2     POLYGON ((120.81137 17.74075, 120.78275 17.714...
# 3     POLYGON ((120.53461 17.53930, 120.53348 17.538...
# 4     POLYGON ((120.69169 17.63382, 120.69412 17.632...
# ...                                                 ...
# 1642  POLYGON ((123.28545 7.71044, 123.31264 7.71036...
# 1643  MULTIPOLYGON (((123.45889 7.61583, 123.45917 7...
# 1644  POLYGON ((123.38792 8.10414, 123.39722 8.08836...
# 1645  POLYGON ((122.68086 7.88831, 122.68091 7.88682...
# 1646  MULTIPOLYGON (((122.41989 7.49679, 122.42042 7...
#
# [1647 rows x 14 columns]

# %%
def shp_to_ee_fmt(geodf):
        data = json.loads(geodf.to_json())
        return data['features'][0]['geometry']['coordinates']

ee.Geometry.MultiPolygon(shp_to_ee_fmt(municities['geometry']))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ee.Geometry({
#   "functionInvocationValue": {
#     "functionName": "GeometryConstructors.MultiPolygon",
#     "arguments": {
#       "coordinates": {
#         "constantValue": [
#           [
#             [
#               [
#                 120.81813049316418,
#                 17.453250885009822
#               ],
#               [
#                 120.80330657958984,
#                 17.449369430541935
#               ],
#               [
#                 120.7892227172855,
#                 17.445249557495174
#               ],
#               [
#                 120.78955841064487,
#                 17.416990280151367
#               ],
#               [
#                 120.78357696533249,
#                 17.416429519653434
#               ],
#               [
#                 120.76431274414108,
#                 17.41608047485363
#               ],
#               [
#                 120.76374816894543,
#                 17.416479110718
#               ],
#               [
#                 120.76293182373047,
#                 17.416639328002987
#               ],
#               [
#                 120.76130676269577,
#                 17.416770935058707
#               ],
#               [
#                 120.7599563598634,
#                 17.41721916198736
#               ],
#               [
#                 120.75927734375034,
#                 17.41743087768566
#               ],
#               [
#                 120.75906372070312,
#                 17.418119430541992
#               ],
#               [
#                 120.75862884521507,
#                 17.419200897216797
#               ],
#               [
#                 120.75723266601562,
#                 17.420190811157454
#               ],
#               [
#                 120.75614166259777,
#                 17.42122077941906
#               ],
#               [
#                 120.75585174560581,
#                 17.422210693359375
#               ],
#               [
#                 120.75499725341808,
#                 17.42366981506359
#               ],
#               [
#                 120.75473022460938,
#                 17.424659729003906
#               ],
#               [
#                 120.75508117675815,
#                 17.425449371338004
#               ],
#               [
#                 120.75521850585972,
#                 17.42687034606928
#               ],
#               [
#                 120.7541427612307,
#                 17.427989959716797
#               ],
#               [
#                 120.75247192382812,
#                 17.42906951904297
#               ],
#               [
#                 120.75064086914097,
#                 17.430370330810604
#               ],
#               [
#                 120.74964904785168,
#                 17.431100845337028
#               ],
#               [
#                 120.7485504150394,
#                 17.43141937255865
#               ],
#               [
#                 120.74748229980469,
#                 17.432870864868107
#               ],
#               [
#                 120.74656677246139,
#                 17.433210372924805
#               ],
#               [
#                 120.74530792236362,
#                 17.43321990966797
#               ],
#               [
#                 120.74347686767578,
#                 17.433940887451172
#               ],
#               [
#                 120.74220275878918,
#                 17.43431091308605
#               ],
#               [
#                 120.74217987060592,
#                 17.434839248657227
#               ],
#               [
#                 120.74291229248047,
#                 17.435699462890625
#               ],
#               [
#                 120.74369812011719,
#                 17.436149597168026
#               ],
#               [
#                 120.74405670166016,
#                 17.436870574951286
#               ],
#               [
#                 120.74488067626964,
#                 17.43757057189947
#               ],
#               [
#                 120.74726867675815,
#                 17.438129425048828
#               ],
#               [
#                 120.74918365478538,
#                 17.43878936767578
#               ],
#               [
#                 120.75035095214844,
#                 17.439289093017635
#               ],
#               [
#                 120.75067901611328,
#                 17.44075012207054
#               ],
#               [
#                 120.7518463134769,
#                 17.444509506225813
#               ],
#               [
#                 120.75074768066406,
#                 17.444599151611328
#               ],
#               [
#                 120.75012207031284,
#                 17.444520950317383
#               ],
#               [
#                 120.7493820190432,
#                 17.4443302154541
#               ],
#               [
#                 120.74841308593784,
#                 17.444400787353516
#               ],
#               [
#                 120.74783325195347,
#                 17.444959640503043
#               ],
#               [
#                 120.74746704101585,
#                 17.445869445800838
#               ],
#               [
#                 120.7475204467778,
#                 17.446680068969783
#               ],
#               [
#                 120.74754333496105,
#                 17.447320938110465
#               ],
#               [
#                 120.74851226806652,
#                 17.448469161987305
#               ],
#               [
#                 120.74980926513717,
#                 17.44984054565441
#               ],
#               [
#                 120.74983215332043,
#                 17.450429916382063
#               ],
#               [
#                 120.74936676025425,
#                 17.451070785522575
#               ],
#               [
#                 120.74857330322266,
#                 17.45116043090826
#               ],
#               [
#                 120.74796295166061,
#                 17.45078086853033
#               ],
#               [
#                 120.74727630615257,
#                 17.450010299682617
#               ],
#               [
#                 120.7464828491211,
#                 17.449449539184684
#               ],
#               [
#                 120.74584197998058,
#                 17.449069976806697
#               ],
#               [
#                 120.74555969238304,
#                 17.449180603027457
#               ],
#               [
#                 120.7432785034182,
#                 17.45027923584007
#               ],
#               [
#                 120.7408218383789,
#                 17.451829910278377
#               ],
#               [
#                 120.7395477294923,
#                 17.452579498291016
#               ],
#               [
#                 120.73721313476562,
#                 17.453540802001953
#               ],
#               [
#                 120.73464965820312,
#                 17.45417976379406
#               ],
#               [
#                 120.73327636718795,
#                 17.454660415649414
#               ],
#               [
#                 120.73217010498047,
#                 17.455320358276367
#               ],
#               [
#                 120.73094177246105,
#                 17.456090927124023
#               ],
#               [
#                 120.72992706298851,
#                 17.457010269165266
#               ],
#               [
#                 120.72769927978527,
#                 17.457620620727653
#               ],
#               [
#                 120.73217010498047,
#                 17.463220596313477
#               ],
#               [
#                 120.73738861083984,
#                 17.476270675659123
#               ],
#               [
#                 120.74114227294922,
#                 17.487049102783317
#               ],
#               [
#                 120.74957275390648,
#                 17.507759094238395
#               ],
#               [
#                 120.75276184082031,
#                 17.516029357910156
#               ],
#               [
#                 120.75377655029297,
#                 17.51837921142601
#               ],
#               [
#                 120.75623321533237,
#                 17.527559280395565
#               ],
#               [
#                 120.76281738281261,
#                 17.54215049743658
#               ],
#               [
#                 120.79149627685547,
#                 17.546030044555664
#               ],
#               [
#                 120.79773712158249,
#                 17.534200668335075
#               ],
#               [
#                 120.80239868164085,
#                 17.527900695800838
#               ],
#               [
#                 120.80928039550781,
#                 17.518770217895508
#               ],
#               [
#                 120.81703186035156,
#                 17.510089874267635
#               ],
#               [
#                 120.8257522583009,
#                 17.503870010375977
#               ],
#               [
#                 120.83899688720714,
#                 17.496440887451115
#               ],
#               [
#                 120.85411834716797,
#                 17.48698043823248
#               ],
#               [
#                 120.8846435546875,
#                 17.469419479370117
#               ],
#               [
#                 120.8662261962894,
#                 17.46478080749523
#               ],
#               [
#                 120.84485626220749,
#                 17.459680557251204
#               ],
#               [
#                 120.8237075805664,
#                 17.45433044433605
#               ],
#               [
#                 120.81813049316418,
#                 17.453250885009822
#               ]
#             ]
#           ]
#         ]
#       },
#       "evenOdd": {
#         "constantValue": true
#       }
#     }
#   }
# })

# %%
def get_viirs_value_2015(geometry):
    viirs_value = viirs2015.reduceRegion(reducer=ee.Reducer.sum(),
                                             geometry=geometry,
                                             scale=500,
                                             maxPixels=1e9).get('average').getInfo()
    return viirs_value
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
collection_name = geemap.shp_to_ee(municities)
collection_name_fc = ee.FeatureCollection(collection_name)
print('FeatureCollection from a string:', collection_name_fc.limit(5).getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# expected str, bytes or os.PathLike object, not GeoDataFrame
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# <ipython-input-36-6e763063a4d0> in <cell line: 2>()
#       1 collection_name = geemap.shp_to_ee(municities)
# ----> 2 collection_name_fc = ee.FeatureCollection(collection_name)
#       3 print('FeatureCollection from a string:', collection_name_fc.limit(5).getInfo())
#
# /usr/local/lib/python3.10/dist-packages/ee/computedobject.py in __call__(cls, *args, **kwargs)
#      26       return args[0]
#      27     else:
# ---> 28       return type.__call__(cls, *args, **kwargs)
#      29
#      30
#
# /usr/local/lib/python3.10/dist-packages/ee/featurecollection.py in __init__(self, args, opt_column)
#      97       super().__init__(args.func, args.args, args.varName)
#      98     else:
# ---> 99       raise ee_exception.EEException(
#     100           'Unrecognized argument type to convert to a FeatureCollection: %s' %
#     101           args)
#
# EEException: Unrecognized argument type to convert to a FeatureCollection: None

# %%
municities['geometry'].apply(get_viirs_value_2015)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# <ipython-input-32-95677c70a36c> in <cell line: 1>()
# ----> 1 municities['geometry'].apply(get_viirs_value_2015)
#
# /usr/local/lib/python3.10/dist-packages/geopandas/geoseries.py in apply(self, func, convert_dtype, args, **kwargs)
#     643     @doc(pd.Series)
#     644     def apply(self, func, convert_dtype=True, args=(), **kwargs):
# --> 645         result = super().apply(func, convert_dtype=convert_dtype, args=args, **kwargs)
#     646         if isinstance(result, GeoSeries):
#     647             if self.crs is not None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1121
#    1122         # self.f is Callable
# -> 1123         return self.apply_standard()
#    1124
#    1125     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1172             else:
#    1173                 values = obj.astype(object)._values
# -> 1174                 mapped = lib.map_infer(
#    1175                     values,
#    1176                     f,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-31-d250e9211344> in get_viirs_value_2015(geometry)
#       1 def get_viirs_value_2015(geometry):
# ----> 2     viirs_value = viirs2015.reduceRegion(reducer=ee.Reducer.sum(),
#       3                                              geometry=geometry,
#       4                                              scale=500,
#       5                                              maxPixels=1e9).get('average').getInfo()
#
# /usr/local/lib/python3.10/dist-packages/ee/apifunction.py in <lambda>(*args, **kwargs)
#     216           # We need the lambda to capture "func" from the enclosing scope.
#     217           # pylint: disable-next=unnecessary-lambda
# --> 218           return lambda *args, **kwargs: func.call(*args, **kwargs)
#     219         bound_function = MakeBoundFunction(api_func)
#     220
#
# /usr/local/lib/python3.10/dist-packages/ee/function.py in call(self, *args, **kwargs)
#      60       to that type.
#      61     """
# ---> 62     return self.apply(self.nameArgs(args, kwargs))
#      63
#      64   def apply(self, named_args):
#
# /usr/local/lib/python3.10/dist-packages/ee/function.py in apply(self, named_args)
#      73       to that type.
#      74     """
# ---> 75     result = computedobject.ComputedObject(self, self.promoteArgs(named_args))
#      76     return Function._promoter(result, self.getReturnType())
#      77
#
# /usr/local/lib/python3.10/dist-packages/ee/function.py in promoteArgs(self, args)
#     101       name = arg_spec['name']
#     102       if name in args:
# --> 103         promoted_args[name] = Function._promoter(args[name], arg_spec['type'])
#     104       elif not arg_spec.get('optional'):
#     105         raise ee_exception.EEException(
#
# /usr/local/lib/python3.10/dist-packages/ee/__init__.py in _Promote(arg, a_class)
#     247       return ApiFunction.call_('Collection.geometry', arg)
#     248     else:
# --> 249       return Geometry(arg)
#     250   elif a_class in ('FeatureCollection', 'Collection'):
#     251     # For now Collection is synonymous with FeatureCollection.
#
# /usr/local/lib/python3.10/dist-packages/ee/computedobject.py in __call__(cls, *args, **kwargs)
#      26       return args[0]
#      27     else:
# ---> 28       return type.__call__(cls, *args, **kwargs)
#      29
#      30
#
# /usr/local/lib/python3.10/dist-packages/ee/geometry.py in __init__(self, geo_json, opt_proj, opt_geodesic, opt_evenOdd)
#      82
#      83     if not Geometry._isValidGeometry(geo_json):
# ---> 84       raise ee_exception.EEException('Invalid GeoJSON geometry.')
#      85
#      86     super().__init__(None, None)
#
# EEException: Invalid GeoJSON geometry.

# %%
viirs2015 = ee.ImageCollection("NOAA/VIIRS/DNB/ANNUAL_V21").filterDate("2015-01-01", "2016-01-01").select('average').first()
viirs2020 = ee.ImageCollection("NOAA/VIIRS/DNB/ANNUAL_V21").filterDate("2020-01-01", "2021-01-01").select('average').first()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# create a split panel map
ph = ee.Feature(ee.FeatureCollection("FAO/GAUL/2015/level0").filter(ee.Filter.eq('ADM0_NAME', 'Philippines')).first()).geometry()

PH_NTL_2015 = viirs2015.clip(ph)
PH_NTL_2020 = viirs2020.clip(ph)

left_layer = geemap.ee_tile_layer(PH_NTL_2015, {},'VIIRS-DNB 2015')
right_layer = geemap.ee_tile_layer(PH_NTL_2020, {},'VIIRS-DNB 2020')

# get the geometry for Philippines from GEE's tagged datasets

map2 = geemap.Map()
map2.centerObject(ph, zoom=6)
map2.add_basemap('SATELLITE')
map2.split_map(left_layer=left_layer, right_layer=right_layer)
map2.addLayerControl()
map2
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[11.692945087539863, 122.90241548028548], controls=(ZoomControl(options=['position', 'zoom_in_text'…

# %%
# municities_shp = ee.FeatureCollection("/MuniCities.shp")
municities_shp = ee.FeatureCollection(municities)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# <ipython-input-27-8934ee56f6cb> in <cell line: 2>()
#       1 # municities_shp = ee.FeatureCollection("/MuniCities.shp")
# ----> 2 municities_shp = ee.FeatureCollection(municities)
#
# /usr/local/lib/python3.10/dist-packages/ee/computedobject.py in __call__(cls, *args, **kwargs)
#      26       return args[0]
#      27     else:
# ---> 28       return type.__call__(cls, *args, **kwargs)
#      29
#      30
#
# /usr/local/lib/python3.10/dist-packages/ee/featurecollection.py in __init__(self, args, opt_column)
#      97       super().__init__(args.func, args.args, args.varName)
#      98     else:
# ---> 99       raise ee_exception.EEException(
#     100           'Unrecognized argument type to convert to a FeatureCollection: %s' %
#     101           args)
#
# EEException: Unrecognized argument type to convert to a FeatureCollection:       ID_0  ISO       NAME_0  ID_1             NAME_1  ID_2       NAME_2  \
# 0      177  PHL  Philippines     1               Abra    20   Sallapadan
# 1      177  PHL  Philippines     1               Abra    21   San Isidro
# 2      177  PHL  Philippines     1               Abra    22     San Juan
# 3      177  PHL  Philippines     1               Abra    23  San Quintin
# 4      177  PHL  Philippines     1               Abra    24        Tayum
# ...    ...  ...          ...   ...                ...   ...          ...
# 1642   177  PHL  Philippines    81  Zamboanga del Sur  1623   San Miguel
# 1643   177  PHL  Philippines    81  Zamboanga del Sur  1624    San Pablo
# 1644   177  PHL  Philippines    81  Zamboanga del Sur  1625      Sominot
# 1645   177  PHL  Philippines    82  Zamboanga Sibugay  1646        Titay
# 1646   177  PHL  Philippines    82  Zamboanga Sibugay  1647     Tungawan
#
#      NL_NAME_2           VARNAME_2           TYPE_2     ENGTYPE_2  \
# 0         None                None  Bayan|Munisipyo  Municipality
# 1         None                None  Bayan|Munisipyo  Municipality
# 2         None                None  Bayan|Munisipyo  Municipality
# 3         None                None  Bayan|Munisipyo  Municipality
# 4         None                None  Bayan|Munisipyo  Municipality
# ...        ...                 ...              ...           ...
# 1642      None                None  Bayan|Munisipyo  Municipality
# 1643      None                None  Bayan|Munisipyo  Municipality
# 1644      None  Don Mariano Marcos  Bayan|Munisipyo  Municipality
# 1645      None                None  Bayan|Munisipyo  Municipality
# 1646      None                None  Bayan|Munisipyo  Municipality
#
#                PROVINCE                                  REGION  \
# 0                  Abra  Cordillera Administrative Region (CAR)
# 1                  Abra  Cordillera Administrative Region (CAR)
# 2                  Abra  Cordillera Administrative Region (CAR)
# 3                  Abra  Cordillera Administrative Region (CAR)
# 4                  Abra  Cordillera Administrative Region (CAR)
# ...                 ...                                     ...
# 1642  Zamboanga del Sur         Zamboanga Peninsula (Region IX)
# 1643  Zamboanga del Sur         Zamboanga Peninsula (Region IX)
# 1644  Zamboanga del Sur         Zamboanga Peninsula (Region IX)
# 1645  Zamboanga Sibugay         Zamboanga Peninsula (Region IX)
# 1646  Zamboanga Sibugay         Zamboanga Peninsula (Region IX)
#
#                                                geometry
# 0     POLYGON ((120.81813 17.45325, 120.80331 17.449...
# 1     POLYGON ((120.62464 17.44141, 120.62530 17.441...
# 2     POLYGON ((120.81137 17.74075, 120.78275 17.714...
# 3     POLYGON ((120.53461 17.53930, 120.53348 17.538...
# 4     POLYGON ((120.69169 17.63382, 120.69412 17.632...
# ...                                                 ...
# 1642  POLYGON ((123.28545 7.71044, 123.31264 7.71036...
# 1643  MULTIPOLYGON (((123.45889 7.61583, 123.45917 7...
# 1644  POLYGON ((123.38792 8.10414, 123.39722 8.08836...
# 1645  POLYGON ((122.68086 7.88831, 122.68091 7.88682...
# 1646  MULTIPOLYGON (((122.41989 7.49679, 122.42042 7...
#
# [1647 rows x 14 columns]

# %%
pprint(municities_shp.geometry().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/ee/data.py in _execute_cloud_call(call, num_retries)
#     353   try:
# --> 354     return call.execute(num_retries=num_retries)
#     355   except googleapiclient.errors.HttpError as e:
#
# /usr/local/lib/python3.10/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131
#
# /usr/local/lib/python3.10/dist-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     937         if resp.status >= 300:
# --> 938             raise HttpError(resp, content, uri=self.uri)
#     939         return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/earthengine-legacy/value:compute?prettyPrint=false&alt=json returned "Collection.loadTable: Collection asset '/MuniCities.shp' not found.". Details: "Collection.loadTable: Collection asset '/MuniCities.shp' not found.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# <ipython-input-26-bc6777be941d> in <cell line: 1>()
# ----> 1 pprint(municities_shp.geometry().getInfo())
#
# /usr/local/lib/python3.10/dist-packages/ee/computedobject.py in getInfo(self)
#     103       The object can evaluate to anything.
#     104     """
# --> 105     return data.computeValue(self)
#     106
#     107   def encode(self, encoder: Optional[Callable[..., Any]]) -> Dict[str, Any]:
#
# /usr/local/lib/python3.10/dist-packages/ee/data.py in computeValue(obj)
#    1038   _maybe_populate_workload_tag(body)
#    1039
# -> 1040   return _execute_cloud_call(
#    1041       _get_cloud_projects()
#    1042       .value()
#
# /usr/local/lib/python3.10/dist-packages/ee/data.py in _execute_cloud_call(call, num_retries)
#     354     return call.execute(num_retries=num_retries)
#     355   except googleapiclient.errors.HttpError as e:
# --> 356     raise _translate_cloud_exception(e)  # pylint: disable=raise-missing-from
#     357
#     358
#
# EEException: Collection.loadTable: Collection asset '/MuniCities.shp' not found.

# %%
geemap.shp_to_ee("/MuniCities.shp")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# No module named 'pycrs'

# %%
zone_stats = viirs2015.reduceRegions(collection=municities_shp, reducer=ee.Reducer.sum(), scale=10).getInfo()
# zone_stats = gpd.GeoDataFrame.from_features(zone_stats, crs='epsg:4326')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/ee/data.py in _execute_cloud_call(call, num_retries)
#     353   try:
# --> 354     return call.execute(num_retries=num_retries)
#     355   except googleapiclient.errors.HttpError as e:
#
# /usr/local/lib/python3.10/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131
#
# /usr/local/lib/python3.10/dist-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     937         if resp.status >= 300:
# --> 938             raise HttpError(resp, content, uri=self.uri)
#     939         return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/earthengine-legacy/value:compute?prettyPrint=false&alt=json returned "Collection.loadTable: Collection asset '/MuniCities.shp' not found.". Details: "Collection.loadTable: Collection asset '/MuniCities.shp' not found.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# <ipython-input-17-93b9468cec0b> in <cell line: 1>()
# ----> 1 zone_stats = viirs2015.reduceRegions(collection=municities_shp, reducer=ee.Reducer.sum(), scale=10).getInfo()
#       2 # zone_stats = gpd.GeoDataFrame.from_features(zone_stats, crs='epsg:4326')
#
# /usr/local/lib/python3.10/dist-packages/ee/collection.py in getInfo(self)
#     155            properties.
#     156     """
# --> 157     return super().getInfo()
#     158
#     159   def limit(
#
# /usr/local/lib/python3.10/dist-packages/ee/computedobject.py in getInfo(self)
#     103       The object can evaluate to anything.
#     104     """
# --> 105     return data.computeValue(self)
#     106
#     107   def encode(self, encoder: Optional[Callable[..., Any]]) -> Dict[str, Any]:
#
# /usr/local/lib/python3.10/dist-packages/ee/data.py in computeValue(obj)
#    1038   _maybe_populate_workload_tag(body)
#    1039
# -> 1040   return _execute_cloud_call(
#    1041       _get_cloud_projects()
#    1042       .value()
#
# /usr/local/lib/python3.10/dist-packages/ee/data.py in _execute_cloud_call(call, num_retries)
#     354     return call.execute(num_retries=num_retries)
#     355   except googleapiclient.errors.HttpError as e:
# --> 356     raise _translate_cloud_exception(e)  # pylint: disable=raise-missing-from
#     357
#     358
#
# EEException: Collection.loadTable: Collection asset '/MuniCities.shp' not found.
